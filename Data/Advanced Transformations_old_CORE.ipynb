# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
super_info_df = pd.read_csv("/Users/Rashad/Documents/GitHub/Applying Advanced Transformations_CORE/Superhero-Transformations/Data/superhero_info.csv")
super_info_df
# Out:
#                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# 0             No Hair    yellow    Unknown
# ...

# %%
super_powers_df = pd.read_csv("/Users/Rashad/Documents/GitHub/Applying Advanced Transformations_CORE/Superhero-Transformations/Data/superhero_powers.csv")
super_powers_df
# Out:
#           hero_names                                             Powers
# 0            3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# ..               ...                                                ...
# 662  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 663             Ymir  Cold Resistance,Durability,Longevity,Super Str...
# 664             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
# [667 rows x 2 columns]

# %%
super_info_df['Hero|Publisher']
# Out:
# 0               A-Bomb|Marvel Comics
# 1       Abe Sapien|Dark Horse Comics
# 2                 Abin Sur|DC Comics
# 3          Abomination|Marvel Comics
# 4        Absorbing Man|Marvel Comics
#                    ...
# 458       Yellowjacket|Marvel Comics
# 459    Yellowjacket II|Marvel Comics
# 460                Yoda|George Lucas
# 461                Zatanna|DC Comics
# 462                   Zoom|DC Comics
# Name: Hero|Publisher, Length: 463, dtype: object

# %%
## save the 2 new columns into the dataframe
#df[['area_code','phone_number']] = df['display_phone'].str.split(' ',expand=True)
#df.head(2)

super_info_df[['Hero','Publisher']] = super_info_df['Hero|Publisher'].str.split('|',expand=True)

# %%
super_info_df
# Out:
#                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# 0             No Hair    yellow    Unknown
# ...

# %%
## drop the original column 
super_info_df = super_info_df.drop(columns='Hero|Publisher')

# %%
super_info_df
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color                                  Measurements             Hero  \
# ...

# %%
super_info_df['Measurements']
# Out:
# 0      {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1       {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2       {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3      {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4      {'Height': '193.0 cm', 'Weight': '122.0 kg'}
#                            ...
# 458     {'Height': '183.0 cm', 'Weight': '83.0 kg'}
# 459     {'Height': '165.0 cm', 'Weight': '52.0 kg'}
# 460      {'Height': '66.0 cm', 'Weight': '17.0 kg'}
# 461     {'Height': '170.0 cm', 'Weight': '57.0 kg'}
# 462     {'Height': '185.0 cm', 'Weight': '81.0 kg'}
# Name: Measurements, Length: 463, dtype: object

# %%
## examining a single value from the "Measurements" col
meas = super_info_df.loc[0,"Measurements"]

print(type(meas))
meas
# Out:
# <class 'str'>
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
## use .str.replace to replace all single quotes
super_info_df['Measurements'] = super_info_df['Measurements'].str.replace("'",'"')

## Apply the json.loads to the full column
super_info_df['Measurements'] = super_info_df['Measurements'].apply(json.loads)
super_info_df['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
## examining a single value from the "Measurements" col
meas = super_info_df.loc[0,"Measurements"]

print(type(meas))
meas
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
h_w = super_info_df['Measurements'].apply(pd.Series)
h_w
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# concat long_lat with original dataframe
super_info_df = pd.concat((super_info_df, h_w), axis = 1)
super_info_df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
## drop the original column 
super_info_df = super_info_df.drop(columns='Measurements')

# %%
super_info_df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
#replacing all " cm" and " kg" in Height and Weight columns.
super_info_df['Height'] = super_info_df['Height'].str.replace(" cm","")
super_info_df['Weight'] = super_info_df['Weight'].str.replace(" kg","")

# %%
super_info_df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height Weight
# 0      Marvel Comics  203.0  441.0
# 1  Dark Horse Comics  191.0   65.0

# %%
super_powers_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
super_powers_df["Powers"]
# Out:
# 0             Agility,Super Strength,Stamina,Super Speed
# 1      Accelerated Healing,Durability,Longevity,Super...
# 2      Agility,Accelerated Healing,Cold Resistance,Du...
# 3                                     Lantern Power Ring
# 4      Accelerated Healing,Intelligence,Super Strengt...
#                              ...
# 662                   Flight,Energy Blasts,Size Changing
# 663    Cold Resistance,Durability,Longevity,Super Str...
# 664    Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665    Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666    Super Speed,Intangibility,Time Travel,Time Man...
# Name: Powers, Length: 667, dtype: object

# %%
## examining a single value from the "Powers" col
sp = super_powers_df.loc[0,"Powers"]

print(type(sp))
sp
# Out:
# <class 'str'>
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
super_powers_df['Powers'] = super_powers_df['Powers'].str.split(",")

# %%
super_powers_df
# Out:
#           hero_names                                             Powers
# 0            3-D Man    [Agility, Super Strength, Stamina, Super Speed]
# 1             A-Bomb  [Accelerated Healing, Durability, Longevity, S...
# 2         Abe Sapien  [Agility, Accelerated Healing, Cold Resistance...
# 3           Abin Sur                               [Lantern Power Ring]
# 4        Abomination  [Accelerated Healing, Intelligence, Super Stre...
# ..               ...                                                ...
# 662  Yellowjacket II             [Flight, Energy Blasts, Size Changing]
# 663             Ymir  [Cold Resistance, Durability, Longevity, Super...
# 664             Yoda  [Agility, Stealth, Danger Sense, Marksmanship,...
# 665          Zatanna  [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666             Zoom  [Super Speed, Intangibility, Time Travel, Time...
#
# [667 rows x 2 columns]

# %%
## exploding the column of lists
exploded = super_powers_df.explode('Powers')

# %%
exploded
# Out:
#     hero_names               Powers
# 0      3-D Man              Agility
# 0      3-D Man       Super Strength
# 0      3-D Man              Stamina
# 0      3-D Man          Super Speed
# 1       A-Bomb  Accelerated Healing
# ..         ...                  ...
# 665    Zatanna      Weather Control
# 666       Zoom          Super Speed
# 666       Zoom        Intangibility
# 666       Zoom          Time Travel
# 666       Zoom    Time Manipulation
#
# [5874 rows x 2 columns]

# %%
cols_to_make = exploded['Powers'].dropna().unique()

# %%
#for col in cols_to_make:
#    exploded[col] = exploded['Powers'].str.contains(col)
#exploded.head()

for col in cols_to_make:
    super_powers_df[col] = super_powers_df['Powers'].str.contains(col)
super_powers_df.head()
# Out:
# C:\Users\Rashad\AppData\Local\Temp\ipykernel_9980\2911754120.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super_powers_df[col] = super_powers_df['Powers'].str.contains(col)
# C:\Users\Rashad\AppData\Local\Temp\ipykernel_9980\2911754120.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super_powers_df[col] = super_powers_df['Powers'].str.contains(col)
# ...

# %%
ohe_super_powers_df = exploded
ohe_super_powers_df
# Out:
#     hero_names               Powers
# 0      3-D Man              Agility
# 0      3-D Man       Super Strength
# 0      3-D Man              Stamina
# 0      3-D Man          Super Speed
# 1       A-Bomb  Accelerated Healing
# ..         ...                  ...
# 665    Zatanna      Weather Control
# 666       Zoom          Super Speed
# 666       Zoom        Intangibility
# 666       Zoom          Time Travel
# 666       Zoom    Time Manipulation
#
# [5874 rows x 2 columns]

# %%
super_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    object
#  9   Weight      463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %%
super_info_df[['Height','Weight']] = super_info_df[['Height','Weight']].astype('float', copy=None, errors='raise')
super_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    float64
#  9   Weight      463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %%
super_info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight
# 0         A-Bomb      Marvel Comics   203.0   441.0
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0
# 2       Abin Sur          DC Comics   185.0    90.0
# 3    Abomination      Marvel Comics   203.0   441.0
# 4  Absorbing Man      Marvel Comics   193.0   122.0

# %%
ohe_super_powers_df.head()
# Out:
#   hero_names               Powers
# 0    3-D Man              Agility
# 0    3-D Man       Super Strength
# 0    3-D Man              Stamina
# 0    3-D Man          Super Speed
# 1     A-Bomb  Accelerated Healing

# %% [markdown]
# # Combining\Merging dataframes into a single dataframe.

# %%
super_info_df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher  Height  Weight
# 0      Marvel Comics   203.0   441.0
# 1  Dark Horse Comics   191.0    65.0

# %%
ohe_super_powers_df.head(2)
# Out:
#   hero_names          Powers
# 0    3-D Man         Agility
# 0    3-D Man  Super Strength

# %%
super_info_df.shape
# Out:
# (463, 10)

# %%
super_powers_df.shape
# Out:
# (667, 169)

# %%
new_ohe_super_powers_df = ohe_super_powers_df.rename(columns={"hero_names":"Hero"})
new_ohe_super_powers_df.head(2)
# Out:
#       Hero          Powers
# 0  3-D Man         Agility
# 0  3-D Man  Super Strength

# %%
MERGED_DF= super_info_df.merge(new_ohe_super_powers_df, how='inner', on=["Hero"])
MERGED_DF
# Out:
#       Gender     Race Alignment Hair color Eye color Skin color     Hero  \
# 0       Male    Human      good    No Hair    yellow    Unknown   A-Bomb
# 1       Male    Human      good    No Hair    yellow    Unknown   A-Bomb
# 2       Male    Human      good    No Hair    yellow    Unknown   A-Bomb
# 3       Male    Human      good    No Hair    yellow    Unknown   A-Bomb
# 4       Male    Human      good    No Hair    yellow    Unknown   A-Bomb
# ...      ...      ...       ...        ...       ...        ...      ...
# 4461  Female    Human      good      Black      blue    Unknown  Zatanna
# 4462    Male  Unknown       bad      Brown       red    Unknown     Zoom
# 4463    Male  Unknown       bad      Brown       red    Unknown     Zoom
# 4464    Male  Unknown       bad      Brown       red    Unknown     Zoom
# 4465    Male  Unknown       bad      Brown       red    Unknown     Zoom
#
#           Publisher  Height  Weight               Powers
# ...

# %% [markdown]
# # 1. Compare the average weight of super heros who have Super Speed to those who do not.

# %%
ohe_super_powers_df['Super Speed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Super Speed'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
super_speed_df = ohe_super_powers_df[ohe_super_powers_df['Super Speed'] == True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Super Speed'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
super_speed_df

# %%
super_speed_df = super_speed_df.rename(columns={"hero_names":"Hero"})

# %%
super_speed_df

# %%
super_info_df.head()

# %%
HERO_W_SS_MERGED = super_speed_df.merge(super_info_df, how='inner', on=["Hero"])
HERO_W_SS_MERGED

# %%
#Finding those Super Heros who don't have Super Speed.

# filtered ohe_super_speed_df to those without Super Speed and saved to new df
no_super_speed_df = ohe_super_powers_df[ohe_super_powers_df['Super Speed'] == False]

#change the name of the column hero_name to Hero so dataframes can be merged and save\replaced same df
no_super_speed_df = no_super_speed_df.rename(columns={"hero_names":"Hero"})

#Inner Merged no_super_speed_df to super_info_df on Hero column and saved to new df
HERO_NO_SS_MERGED = no_super_speed_df.merge(super_info_df, how='inner', on=["Hero"])

# %%
print(f"Average weight of Super Heros with Super Speed is:  {HERO_W_SS_MERGED['Weight'].mean().round(3)}")
print(f"Average weight of Super Heros without Super Speed is:  {HERO_NO_SS_MERGED['Weight'].mean().round(3)}")

# %%
MERGED_DF.groupby('Super Speed')['Weight'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [41], line 1
# ----> 1 MERGED_DF.groupby('Super Speed')['Weight'].mean()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\frame.py:8399, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
#    8397 axis = self._get_axis_number(axis)
# -> 8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    8402     axis=axis,
#    8403     level=level,
#    8404     as_index=as_index,
#    8405     sort=sort,
#    8406     group_keys=group_keys,
#    8407     squeeze=squeeze,
#    8408     observed=observed,
#    8409     dropna=dropna,
#    8410 )
#
# ...

# %% [markdown]
# # 2. What is the average height of heroes for each publisher?

# %%
super_info_df.head(3)

# %%
super_info_df.groupby('Publisher').Height.mean()
